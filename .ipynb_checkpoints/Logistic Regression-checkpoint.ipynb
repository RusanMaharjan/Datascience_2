# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv('D:/Broadway/Data Science - 2/HR_Dataset Refresh.csv')
df.head()
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
# 2            5       5            3                       0   64955  ...
# 3            1       5            3                       0   64991  ...
# 4            5       5            3                       0   50825  ...
#
#       ManagerName  ManagerID RecruitmentSource PerformanceScore  \
# ...

# %%
df.columns
# Out:
# Index(['Employee_Name', 'EmpID', 'MarriedID', 'MaritalStatusID', 'GenderID',
#        'EmpStatusID', 'DeptID', 'PerfScoreID', 'FromDiversityJobFairID',
#        'Salary', 'Termd', 'PositionID', 'Position', 'State', 'Zip', 'DOB',
#        'Gender', 'MaritalDesc', 'CitizenDesc', 'HispanicLatino', 'RaceDesc',
#        'DateofHire', 'DateofTermination', 'TermReason', 'EmploymentStatus',
#        'Department', 'ManagerName', 'ManagerID', 'RecruitmentSource',
#        'PerformanceScore', 'EngagementSurvey', 'EmpSatisfaction',
#        'SpecialProjectsCount', 'LastPerformanceReview_Date', 'DaysLateLast30',
#        'Absences'],
#       dtype='object')

# %%
features = ['PerfScoreID', 'Salary', 'PositionID', 'EngagementSurvey', 'EmpSatisfaction','SpecialProjectsCount', 'DaysLateLast30','Absences']
target = 'Termd' # 0 -> Active , 1 -> Termination

# %%
X = df[features]
Y = df[target]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(
    X, Y, test_size=0.2, random_state=42, 
    stratify=Y # for equal distribution of target values
)

# %%
scaler = StandardScaler()

# %%
X_train_scale = scaler.fit_transform(X_train) # Xi-mean/sd
X_test_scale = scaler.transform(X_test)

# %%
model = LogisticRegression(
    solver='liblinear', class_weight='balanced', random_state=42
)

# %%
model.fit(X_train_scale, Y_train)
# Out:
# LogisticRegression(class_weight='balanced', random_state=42, solver='liblinear')

# %%
Y_pred = model.predict(X_test_scale)

# %%
# X -> Actual Record CM -> Predicted
# Y -> Predicted Record CM -> Actual

# %%
cm = confusion_matrix(Y_test, Y_pred)
cr = classification_report(Y_test, Y_pred)

# %%
print(cm)
# Out:
# [[53 25]
#  [15 24]]

# %%
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.68      0.73        78
#            1       0.49      0.62      0.55        39
#
#     accuracy                           0.66       117
#    macro avg       0.63      0.65      0.64       117
# weighted avg       0.68      0.66      0.67       117

# %%
# weighted avg -> precision

# (precision[0]*support)+(precision[1]*support)/117

# macro avg -> Precision
# precision[0]+Precision[1]/2

# %%
sns.heatmap(cm, annot=True, xticklabels=['Predicted Active[0]', 'Predicted Termination[1]'],
           yticklabels=['Actual Active[0]', 'Actual Termination[1]'])
plt.savefig('cm.png')

# %%
# True Negative           False Positive
# False Negative          True Positive

# %%
input_data = {
    'PerfScoreID': [1, 1, 4], 
    'Salary': [50000, 60000, 10000], 
    'PositionID': [0, 1, 3], 
    'EngagementSurvey': [4.6, 3, 2.2], 
    'EmpSatisfaction': [3, 4, 5],
    'SpecialProjectsCount': [3, 5, 10], 
    'DaysLateLast30': [0, 0, 1],
    'Absences': [4, 2, 0]
}

# %%
X_new = pd.DataFrame(input_data)

# %%
X_new_scale = scaler.transform(X_new)

# %%
Y_new_pred = model.predict(X_new_scale)

# %%
X_new['Predicted_Status'] = Y_new_pred
X_new['Predicted_Status'] = X_new['Predicted_Status'].replace({1: 'Likely to be Termimate',
                                                               0: 'Likely to be Active'})

# %%
X_new
# Out:
#    PerfScoreID  Salary  PositionID  EngagementSurvey  EmpSatisfaction  \
# 0            1   50000           0               4.6                3
# 1            1   60000           1               3.0                4
# 2            4   10000           3               2.2                5
#
#    SpecialProjectsCount  DaysLateLast30  Absences        Predicted_Status
# 0                     3               0         4  Likely to be Termimate
# 1                     5               0         2  Likely to be Termimate
# 2                    10               1         0     Likely to be Active

# %%
cv = pd.read_csv('D:/Broadway/Data Science - 2/Cardiovascular_Disease.csv')

# %%
cv
# Out:
#           id        age  gender  height  weight  ap_hi  ap_lo  cholesterol  \
# 0          0  50.391781       2     168    62.0    110     80            1
# 1          1  55.419178       1     156    85.0    140     90            3
# 2          2  51.663014       1     165    64.0    130     70            3
# 3          3  48.282192       2     169    82.0    150    100            1
# 4          4  47.873973       1     156    56.0    100     60            1
# ...      ...        ...     ...     ...     ...    ...    ...          ...
# 69995  99993  52.712329       2     168    76.0    120     80            1
# 69996  99995  61.920548       1     158   126.0    140     90            2
# 69997  99996  52.235616       2     183   105.0    180     90            3
# 69998  99998  61.454795       1     163    72.0    135     80            1
# 69999  99999  56.273973       1     170    72.0    120     80            2
#
#        gluc  smoke  alco  active  cardio
# ...

# %%
cv['age'] = cv['age']/365

# %%
filtered_data = cv['ap_hi'] > 180

# %%
cv[filtered_data]
# Out:
#           id        age  gender  height  weight  ap_hi  ap_lo  cholesterol  \
# 101      136  51.282192       1     167    80.0    190     90            2
# 559      805  55.972603       2     173   101.0    200   1000            1
# 649      928  49.835616       1     166    57.0    190   1100            1
# 965     1341  54.126027       1     155    83.0    190     90            2
# 1328    1863  57.706849       2     174   106.0    220    120            3
# ...      ...        ...     ...     ...     ...    ...    ...          ...
# 69329  99019  54.295890       1     145    62.0    240    130            1
# 69370  99089  40.263014       1     170    74.0   2000    100            2
# 69405  99139  56.213699       1     159    60.0    190    120            1
# 69440  99182  63.400000       2     180   123.0    190     99            2
# 69894  99835  46.183562       1     160    70.0    200    100            1
#
#        gluc  smoke  alco  active  cardio
# ...

# %%
# Content-based filtering
# Colaborative Filtering
# Hybrid Filtering -> Content + Colaborative

# Cold Start Problem
