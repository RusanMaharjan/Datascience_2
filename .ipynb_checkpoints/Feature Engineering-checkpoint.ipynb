# %%
import pandas as pd

# %%
hr = pd.read_csv('HR_Dataset Refresh.csv')
# Top 5
hr.head()
# Bottom 5
hr.tail()
# Out:
#          Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 577   Anderson, Carol   10069          0                2         0
# 578  Anderson, Linda    10002          0                0         0
# 579    Andreola, Colby  10194          0                0         0
# 580        Athwal, Sam  10062          0                4         1
# 581   Bachiochi, Linda  10114          0                0         0
#
#      EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 577            5       5            3                       0   50825  ...
# 578            1       5            4                       0   57568  ...
# 579            1       4            3                       0   95660  ...
# 580            1       5            3                       0   59365  ...
# 581            3       5            3                       1   47837  ...
#
#          ManagerName  ManagerID   RecruitmentSource PerformanceScore  \
# ...

# %%
# Regular Expression (Regex)
# ,./+-&^%$@!$%^&()[]{}
# Replace(find, value_replace, regex=False)

# White Space
# '     Production Department     '
# Strip()

# %%
hr['Employee_Name'] = hr['Employee_Name'].str.replace(',',' ',regex=False)

# %%
hr
# Out:
#                 Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0         Adinolfi  Wilson  K  10026          0                0         1
# 1    Ait Sidi  Karthikeyan     10084          1                1         1
# 2           Akinkuolie  Sarah  10196          1                1         0
# 3                Alagbe Trina  10088          1                1         0
# 4            Anderson  Carol   10069          0                2         0
# ..                        ...    ...        ...              ...       ...
# 577          Anderson  Carol   10069          0                2         0
# 578         Anderson  Linda    10002          0                0         0
# 579           Andreola  Colby  10194          0                0         0
# 580               Athwal  Sam  10062          0                4         1
# 581          Bachiochi  Linda  10114          0                0         0
#
# ...

# %%
prod_dep = hr['Department'] == 'Production'
hr[prod_dep]
# Out:
# Empty DataFrame
# Columns: [Employee_Name, EmpID, MarriedID, MaritalStatusID, GenderID, EmpStatusID, DeptID, PerfScoreID, FromDiversityJobFairID, Salary, Termd, PositionID, Position, State, Zip, DOB, Gender, MaritalDesc, CitizenDesc, HispanicLatino, RaceDesc, DateofHire, DateofTermination, TermReason, EmploymentStatus, Department, ManagerName, ManagerID, RecruitmentSource, PerformanceScore, EngagementSurvey, EmpSatisfaction, SpecialProjectsCount, LastPerformanceReview_Date, DaysLateLast30, Absences]
# Index: []
#
# [0 rows x 36 columns]

# %%
# Remove White Space
hr['Department'] = hr['Department'].str.strip()

# %%
hr['Department']
# Out:
# 0                Production
# 1                     IT/IS
# 2                Production
# 3                Production
# 4                Production
#                ...
# 577              Production
# 578              Production
# 579    Software Engineering
# 580              Production
# 581              Production
# Name: Department, Length: 582, dtype: object

# %%
hr['DateofHire']
# Out:
# 0        7/5/2011
# 1       3/30/2015
# 2        7/5/2011
# 3        1/7/2008
# 4       7/11/2011
#           ...
# 577     7/11/2011
# 578      1/9/2012
# 579    11/10/2014
# 580     9/30/2013
# 581      7/6/2009
# Name: DateofHire, Length: 582, dtype: object

# %%
hr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 582 entries, 0 to 581
# Data columns (total 36 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Employee_Name               582 non-null    object
#  1   EmpID                       582 non-null    int64
#  2   MarriedID                   582 non-null    int64
#  3   MaritalStatusID             582 non-null    int64
#  4   GenderID                    582 non-null    int64
#  5   EmpStatusID                 582 non-null    int64
#  6   DeptID                      582 non-null    int64
#  7   PerfScoreID                 582 non-null    int64
#  8   FromDiversityJobFairID      582 non-null    int64
#  9   Salary                      582 non-null    int64
#  10  Termd                       582 non-null    int64
#  11  PositionID                  582 non-null    int64
#  12  Position                    582 non-null    object
# ...

# %%
hr['DateofHire'] = pd.to_datetime(hr['DateofHire'])

# %%
hr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 582 entries, 0 to 581
# Data columns (total 39 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Employee_Name               582 non-null    object
#  1   EmpID                       582 non-null    int64
#  2   MarriedID                   582 non-null    int64
#  3   MaritalStatusID             582 non-null    int64
#  4   GenderID                    582 non-null    int64
#  5   EmpStatusID                 582 non-null    int64
#  6   DeptID                      582 non-null    int64
#  7   PerfScoreID                 582 non-null    int64
#  8   FromDiversityJobFairID      582 non-null    int64
#  9   Salary                      582 non-null    int64
#  10  Termd                       582 non-null    int64
#  11  PositionID                  582 non-null    int64
#  12  Position                    582 non-null    object
# ...

# %% [markdown]
# # Extract first name, middle name and last name of employees

# %%
# split(find, num_of_column=index, expand=True)
# Employee_Name
hr[['First_Name', 'Middle_Name', 'Last_Name']] = hr['Employee_Name'].str.split(' ',n=2, expand=True)

# %%
# first_name  = pd.Series(['A', 'B'])

# %%
hr_data = {
    'first_name': ['a', 'b'],
    'middle_name': ['c', 'd'],
    'last_name': ['e', 'f']
}

# %%
names = pd.DataFrame(hr_data)

# %%
names
# Out:
#   first_name middle_name last_name
# 0          a           c         e
# 1          b           d         f

# %%
hr['Employee_Name']
# Out:
# 0           Adinolfi  Wilson  K
# 1      Ait Sidi  Karthikeyan
# 2             Akinkuolie  Sarah
# 3                  Alagbe Trina
# 4              Anderson  Carol
#                  ...
# 577            Anderson  Carol
# 578           Anderson  Linda
# 579             Andreola  Colby
# 580                 Athwal  Sam
# 581            Bachiochi  Linda
# Name: Employee_Name, Length: 582, dtype: object

# %%
hr
# Out:
#                 Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0         Adinolfi  Wilson  K  10026          0                0         1
# 1    Ait Sidi  Karthikeyan     10084          1                1         1
# 2           Akinkuolie  Sarah  10196          1                1         0
# 3                Alagbe Trina  10088          1                1         0
# 4            Anderson  Carol   10069          0                2         0
# ..                        ...    ...        ...              ...       ...
# 577          Anderson  Carol   10069          0                2         0
# 578         Anderson  Linda    10002          0                0         0
# 579           Andreola  Colby  10194          0                0         0
# 580               Athwal  Sam  10062          0                4         1
# 581          Bachiochi  Linda  10114          0                0         0
#
# ...

# %% [markdown]
# # Extract Year, Month and Day

# %%
hr['Hire_Year'] = hr['DateofHire'].dt.year

# %%
hr['Hire_Month'] = hr['DateofHire'].dt.month
hr['Hire_Day'] = hr['DateofHire'].dt.day

# %%
hr.head()
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi  Wilson  K  10026          0                0         1
# 1  Ait Sidi  Karthikeyan     10084          1                1         1
# 2         Akinkuolie  Sarah  10196          1                1         0
# 3              Alagbe Trina  10088          1                1         0
# 4          Anderson  Carol   10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
# 2            5       5            3                       0   64955  ...
# 3            1       5            3                       0   64991  ...
# 4            5       5            3                       0   50825  ...
#
#    SpecialProjectsCount  LastPerformanceReview_Date DaysLateLast30 Absences  \
# ...

# %%
hr['Month_Name'] = hr['DateofHire'].dt.month_name()
hr['Day_Name'] = hr['DateofHire'].dt.day_name()

# %%
hr
# Out:
#                 Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0         Adinolfi  Wilson  K  10026          0                0         1
# 1    Ait Sidi  Karthikeyan     10084          1                1         1
# 2           Akinkuolie  Sarah  10196          1                1         0
# 3                Alagbe Trina  10088          1                1         0
# 4            Anderson  Carol   10069          0                2         0
# ..                        ...    ...        ...              ...       ...
# 577          Anderson  Carol   10069          0                2         0
# 578         Anderson  Linda    10002          0                0         0
# 579           Andreola  Colby  10194          0                0         0
# 580               Athwal  Sam  10062          0                4         1
# 581          Bachiochi  Linda  10114          0                0         0
#
# ...

# %%
fraud = pd.read_csv('Fraud Detection Dataset.csv')
fraud.head()
# Out:
#   Transaction_ID  User_ID  Transaction_Amount Transaction_Type  \
# 0             T1     4174             1292.76   ATM Withdrawal
# 1             T2     4507             1554.58   ATM Withdrawal
# 2             T3     1860             2395.02   ATM Withdrawal
# 3             T4     2294              100.10     Bill Payment
# 4             T5     2130             1490.50      POS Payment
#
#    Time_of_Transaction Device_Used       Location  \
# 0                 16.0      Tablet  San Francisco
# 1                 13.0      Mobile       New York
# 2                  NaN      Mobile            NaN
# 3                 15.0     Desktop        Chicago
# 4                 19.0      Mobile  San Francisco
#
#    Previous_Fraudulent_Transactions  Account_Age  \
# 0                                 0          119
# 1                                 4           79
# 2                                 3          115
# 3                                 4            3
# ...

# %%
fraud.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51000 entries, 0 to 50999
# Data columns (total 12 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Transaction_ID                    51000 non-null  object
#  1   User_ID                           51000 non-null  int64
#  2   Transaction_Amount                48480 non-null  float64
#  3   Transaction_Type                  51000 non-null  object
#  4   Time_of_Transaction               48448 non-null  float64
#  5   Device_Used                       48527 non-null  object
#  6   Location                          48453 non-null  object
#  7   Previous_Fraudulent_Transactions  51000 non-null  int64
#  8   Account_Age                       51000 non-null  int64
#  9   Number_of_Transactions_Last_24H   51000 non-null  int64
#  10  Payment_Method                    48531 non-null  object
# ...

# %%
fraud['Transaction_Type'].unique()
# Out:
# array(['ATM Withdrawal', 'Bill Payment', 'POS Payment', 'Bank Transfer',
#        'Online Purchase'], dtype=object)

# %%
fraud['Device_Used'].unique()
# Out:
# array(['Tablet', 'Mobile', 'Desktop', nan, 'Unknown Device'], dtype=object)

# %%
fraud['Transaction_Type'].nunique()
# Out:
# 5

# %%
fraud['Transaction_ID'].nunique()
# Out:
# 50000

# %%
# fraud['Time_of_Transaction'].astype(int)

# %%
fraud.isnull().sum()
# Out:
# Transaction_ID                      0
# User_ID                             0
# Transaction_Amount                  0
# Transaction_Type                    0
# Time_of_Transaction                 0
# Device_Used                         0
# Location                            0
# Previous_Fraudulent_Transactions    0
# Account_Age                         0
# Number_of_Transactions_Last_24H     0
# Payment_Method                      0
# Fraudulent                          0
# dtype: int64

# %%
device_mode = fraud['Device_Used'].mode()
device_mode
# Out:
# 0    Desktop
# Name: Device_Used, dtype: object

# %%
fraud['Device_Used'] = fraud['Device_Used'].fillna('Unknown Device')

# %%
fraud['Device_Used'].unique()
# Out:
# array(['Tablet', 'Mobile', 'Desktop', 'Unknown Device'], dtype=object)

# %%
fraud['Time_of_Transaction'].unique()
# Out:
# array([16., 13., nan, 15., 19.,  2.,  3., 20.,  0., 12., 21., 14.,  7.,
#         4., 17., 10.,  5.,  8., 11., 18.,  1., 22.,  9.,  6., 23.])

# %%
fraud['Location'].unique()
# Out:
# array(['San Francisco', 'New York', 'No Location', 'Chicago', 'Boston',
#        'Houston', 'Miami', 'Los Angeles', 'Seattle'], dtype=object)

# %%
fraud['Location'] = fraud['Location'].fillna('No Location')

# %%
mean_amount = fraud['Transaction_Amount'].median()

# %%
fraud['Transaction_Amount'] = fraud['Transaction_Amount'].fillna(mean_amount)

# %%
fraud['Time_of_Transaction'] = fraud['Time_of_Transaction'].fillna(0)

# %%
fraud['Payment_Method'] = fraud['Payment_Method'].fillna('Unknown Method')

# %%
fraud.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51000 entries, 0 to 50999
# Data columns (total 12 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Transaction_ID                    51000 non-null  object
#  1   User_ID                           51000 non-null  int64
#  2   Transaction_Amount                51000 non-null  float64
#  3   Transaction_Type                  51000 non-null  object
#  4   Time_of_Transaction               51000 non-null  int64
#  5   Device_Used                       51000 non-null  object
#  6   Location                          51000 non-null  object
#  7   Previous_Fraudulent_Transactions  51000 non-null  int64
#  8   Account_Age                       51000 non-null  int64
#  9   Number_of_Transactions_Last_24H   51000 non-null  int64
#  10  Payment_Method                    51000 non-null  object
# ...

# %%
fraud['Time_of_Transaction'] = fraud['Time_of_Transaction'].astype(int)

# %%
fraud['Transaction_ID'].drop_duplicates()
# Out:
# 0            T1
# 1            T2
# 2            T3
# 3            T4
# 4            T5
#           ...
# 49995    T49996
# 49996    T49997
# 49997    T49998
# 49998    T49999
# 49999    T50000
# Name: Transaction_ID, Length: 50000, dtype: object

# %%
fraud.to_csv('Cleaned_Fraud_Dataset.csv', index=False)

# %%
fraud
# Out:
#       Transaction_ID  User_ID  Transaction_Amount Transaction_Type  \
# 0                 T1     4174             1292.76   ATM Withdrawal
# 1                 T2     4507             1554.58   ATM Withdrawal
# 2                 T3     1860             2395.02   ATM Withdrawal
# 3                 T4     2294              100.10     Bill Payment
# 4                 T5     2130             1490.50      POS Payment
# ...              ...      ...                 ...              ...
# 50995         T33982     2339             3112.51     Bill Payment
# 50996         T31261     2152             2897.15  Online Purchase
# 50997         T12293     3345             2204.43      POS Payment
# 50998         T42287     1518             4787.17      POS Payment
# 50999         T13665     2315              814.72      POS Payment
#
#        Time_of_Transaction Device_Used       Location  \
# 0                       16      Tablet  San Francisco
# ...
