# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import classification_report

# %%
df = pd.read_csv('D:/Broadway/Data Science - 2/student.csv')
df.head()
# Out:
#   school sex  age address famsize Pstatus                           Medu  \
# 0     GP   F   18       U     GT3       A               higher education
# 1     GP   F   17       U     GT3       T  primary education (4th grade)
# 2     GP   F   15       U     LE3       T  primary education (4th grade)
# 3     GP   F   15       U     GT3       T               higher education
# 4     GP   F   16       U     GT3       T            secondary education
#
#                             Fedu     Mjob      Fjob  ...     famrel freetime  \
# 0               higher education  at_home   teacher  ...  very good   medium
# 1  primary education (4th grade)  at_home     other  ...  excellent   medium
# 2  primary education (4th grade)  at_home     other  ...  very good   medium
# 3               5th to 9th grade   health  services  ...       good      low
# 4            secondary education    other     other  ...  very good   medium
#
#     goout      Dalc      Walc     health absences  G1  G2  G3
# ...

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
df['health'].unique()
# Out:
# array(['good', 'excellent', 'very bad', 'bad', 'very good'], dtype=object)

# %%
m_edu_id = {
    'primary education (4th grade)': 0,
    '5th to 9th grade': 1,
    'secondary education': 2,
    'higher education': 3,
    'none': 4
}
df['Medu_ID'] = df['Medu'].map(m_edu_id)

# %%
f_edu_id = {
    'primary education (4th grade)': 0,
    '5th to 9th grade': 1,
    'secondary education': 2,
    'higher education': 3,
    'none': 4
}
df['Fedu_ID'] = df['Fedu'].map(f_edu_id)

# %%
travel_id = {
    '<15 min.': 0,
    '15 to 30 min.': 1, 
    '30 min. to 1 hour': 2, 
    '>1 hour': 3
}
df['traveltime_id'] = df['traveltime'].map(travel_id)

# %%
study_id = {
    '<2 hours': 0, 
    '2 to 5 hours': 1, 
    '5 to 10 hours': 2, 
    '>10 hours': 3
}
df['studytime_id'] = df['studytime'].map(study_id)

# %%
internet_id = {
    'no': 0, 
    'yes': 1
}
df['internet_id'] = df['internet'].map(internet_id)

# %%
goout_id = {
    'very low': 0, 
    'low': 1, 
    'medium': 2, 
    'high': 3, 
    'very high': 4
}
df['goout_id'] = df['goout'].map(goout_id)

# %%
dalc_id = {
    'very low': 0, 
    'low': 1, 
    'medium': 2, 
    'high': 3, 
    'very high': 4
}
df['dalc_id'] = df['Dalc'].map(dalc_id)

# %%
walc_id = {
    'very low': 0, 
    'low': 1, 
    'medium': 2, 
    'high': 3, 
    'very high': 4
}
df['walc_id'] = df['Walc'].map(walc_id)

# %%
health_id = {
    'very bad': 0, 
    'bad': 1,
    'good': 2, 
    'very good': 3,
    'excellent': 4  
}
df['health_id'] = df['health'].map(health_id)

# %%
def grade(score):
    if score >= 16:
        return 'A'
    elif score >= 14 and score < 16:
        return 'B'
    elif score >= 10 and score < 14:
        return 'C'
    else:
        return 'Fail'

# %%
df['Grade'] = df['G3'].apply(grade)

# %% [markdown]
# # label encoding

# %%
le = LabelEncoder()

# %%
df['grade_id'] = le.fit_transform(df['Grade'])

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3', 'Medu_ID', 'Fedu_ID',
#        'traveltime_id', 'studytime_id', 'internet_id', 'goout_id', 'dalc_id',
#        'walc_id', 'health_id', 'Grade', 'grade_id'],
#       dtype='object')

# %%
features = ['Medu_ID', 'Fedu_ID', 'traveltime_id', 'studytime_id', 'internet_id', 'goout_id', 'dalc_id',
            'walc_id', 'health_id', 'failures', 'absences', 'G1', 'G2']
target = 'grade_id'

# %%
X = df[features]
Y = df[target]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(
    X, Y, test_size=0.2, random_state=42
)

# %%
scaler = StandardScaler()
X_train_scale = scaler.fit_transform(X_train) # Learning + implement
X_test_scale = scaler.transform(X_test) # Implement

# %%
error_rate = []
k_range = range(1, 21)

# %%
for i in k_range:
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train_scale, Y_train)
    knn_pred = knn.predict(X_test_scale)
    error_rate.append(np.mean(knn_pred != Y_test))

# %%
plt.plot(k_range, error_rate, marker='o')

# %%
model = KNeighborsClassifier(n_neighbors=8) # optimal number of K
model.fit(X_train_scale, Y_train)
Y_pred = model.predict(X_test_scale)

# %%
cr = classification_report(Y_test, Y_pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.40      0.50        10
#            1       0.67      0.50      0.57        16
#            2       0.57      0.88      0.70        26
#            3       0.86      0.67      0.75        27
#
#     accuracy                           0.67        79
#    macro avg       0.69      0.61      0.63        79
# weighted avg       0.70      0.67      0.66        79
